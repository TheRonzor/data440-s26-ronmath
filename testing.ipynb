# %%
from importlib import reload

import src.ronmath as rm
reload(rm);

# %%
x = rm.Rational(20,30)
y = rm.Rational(4,5)

# %%
z1 = rm.Complex(x,y)
z2 = rm.Complex(y,x)

# %%
z1
# Out:
# 20/30 + 4/5i
